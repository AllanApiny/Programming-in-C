# %% [markdown]
# <a href="https://colab.research.google.com/github/AllanApiny/Programming-in-C/blob/main/New_House_Price_Prediction_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_pd=pd.read_csv("housing.csv")

# %%
housing_pd
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing_pd_shuffled=housing_pd.sample(n=len(housing_pd),random_state=1)

# %%
housing_pd_shuffled
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4712     -118.36     34.06                39.0       2810.0           670.0
# 2151     -119.78     36.78                37.0       2185.0           455.0
# 15927    -122.42     37.73                46.0       1819.0           411.0
# 82       -122.28     37.81                52.0        340.0            97.0
# 8161     -118.13     33.82                37.0       1530.0           290.0
# ...          ...       ...                 ...          ...             ...
# 10955    -117.88     33.76                17.0       1768.0           474.0
# 17289    -119.63     34.42                42.0       1765.0           263.0
# 5192     -118.26     33.93                42.0       1433.0           295.0
# 12172    -117.16     33.73                10.0       2381.0           454.0
# 235      -122.20     37.79                35.0       1802.0           459.0
#
# ...

# %%
housing_pd_final=housing_pd_shuffled.join(pd.get_dummies(housing_pd_shuffled['ocean_proximity'])).drop('ocean_proximity',axis=1)

# %%
housing_pd_final
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4712     -118.36     34.06                39.0       2810.0           670.0
# 2151     -119.78     36.78                37.0       2185.0           455.0
# 15927    -122.42     37.73                46.0       1819.0           411.0
# 82       -122.28     37.81                52.0        340.0            97.0
# 8161     -118.13     33.82                37.0       1530.0           290.0
# ...          ...       ...                 ...          ...             ...
# 10955    -117.88     33.76                17.0       1768.0           474.0
# 17289    -119.63     34.42                42.0       1765.0           263.0
# 5192     -118.26     33.93                42.0       1433.0           295.0
# 12172    -117.16     33.73                10.0       2381.0           454.0
# 235      -122.20     37.79                35.0       1802.0           459.0
#
# ...

# %%
housing_pd_final=housing_pd_final[['longitude',	'latitude',	'housing_median_age',	'total_rooms',	'total_bedrooms',	'population','households','median_income','<1H OCEAN',	'INLAND',	'ISLAND',	'NEAR BAY',	'NEAR OCEAN','median_house_value']]

# %%
housing_pd_final
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4712     -118.36     34.06                39.0       2810.0           670.0
# 2151     -119.78     36.78                37.0       2185.0           455.0
# 15927    -122.42     37.73                46.0       1819.0           411.0
# 82       -122.28     37.81                52.0        340.0            97.0
# 8161     -118.13     33.82                37.0       1530.0           290.0
# ...          ...       ...                 ...          ...             ...
# 10955    -117.88     33.76                17.0       1768.0           474.0
# 17289    -119.63     34.42                42.0       1765.0           263.0
# 5192     -118.26     33.93                42.0       1433.0           295.0
# 12172    -117.16     33.73                10.0       2381.0           454.0
# 235      -122.20     37.79                35.0       1802.0           459.0
#
# ...

# %%
housing_pd_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20640 entries, 4712 to 235
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   <1H OCEAN           20640 non-null  bool
#  9   INLAND              20640 non-null  bool
#  10  ISLAND              20640 non-null  bool
#  11  NEAR BAY            20640 non-null  bool
#  12  NEAR OCEAN          20640 non-null  bool
#  13  median_house_value  20640 non-null  float64
# dtypes: bool(5), float64(9)
# memory usage: 2.2 MB

# %%
housing_pd_final.dropna(inplace=True)
# Out:
# <ipython-input-16-883561c55831>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_pd_final.dropna(inplace=True)

# %%
housing_pd_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 4712 to 235
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   <1H OCEAN           20433 non-null  bool
#  9   INLAND              20433 non-null  bool
#  10  ISLAND              20433 non-null  bool
#  11  NEAR BAY            20433 non-null  bool
#  12  NEAR OCEAN          20433 non-null  bool
#  13  median_house_value  20433 non-null  float64
# dtypes: bool(5), float64(9)
# memory usage: 1.7 MB

# %%
train_pd, test_pd, val_pd=housing_pd_final[:18000],housing_pd_final[18000:19217],housing_pd_final[19215:]

# %%
len(train_pd), len(test_pd), len(val_pd)
# Out:
# (18000, 1217, 1218)

# %%
from re import X
X_train, y_train=train_pd.drop('median_house_value',axis=1), train_pd['median_house_value']
X_val, y_val=val_pd.drop('median_house_value',axis=1), val_pd['median_house_value']
X_test, y_test=test_pd.drop('median_house_value',axis=1), test_pd['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit_transform(X_train[:8])

def preprocessor(X):
  A=X.copy()
  A.iloc[:,:8]=StandardScaler().fit_transform(A.iloc[:,:8])
  return A


X_train=preprocessor(X_train)
X_val=preprocessor(X_val)
X_test=preprocessor(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse

lm=LinearRegression().fit(X_train,y_train)
mse(lm.predict(X_train),y_train,squared=False),mse(lm.predict(X_val),y_val,squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (68593.05578127236, 71255.49069089237)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=15).fit(X_train,y_train)
mse(knn.predict(X_train),y_train,squared=False),mse(knn.predict(X_val),y_val,squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (55797.60309166373, 61904.89714713264)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(max_depth=10).fit(X_train,y_train)
mse(rf.predict(X_train),y_train,squared=False),mse(rf.predict(X_val),y_val,squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (43490.92489194302, 61741.82653877301)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor(n_estimators=170).fit(X_train,y_train)
mse(gb.predict(X_train),y_train,squared=False),mse(gb.predict(X_val),y_val,squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (49806.97204725272, 58405.20602503874)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

simple_nn=Sequential()
simple_nn.add(InputLayer((13,)))
simple_nn.add(Dense(2,'relu'))
simple_nn.add(Dense(1,'linear'))

opt=Adam(learning_rate=.1)
cp=ModelCheckpoint('models/simple_nn.keras',save_best_only=True)
simple_nn.compile(optimizer=opt,loss='mse',metrics=[RootMeanSquaredError()])
simple_nn.fit(x=X_train,y=y_train,validation_data=(X_val,y_val),epochs=100,callbacks=[cp])
# Out:
# Epoch 1/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 54122622976.0000 - root_mean_squared_error: 232618.5000 - val_loss: 41103941632.0000 - val_root_mean_squared_error: 202741.0781
# Epoch 2/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35307048960.0000 - root_mean_squared_error: 187770.0938 - val_loss: 23473637376.0000 - val_root_mean_squared_error: 153211.0938
# Epoch 3/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 21401952256.0000 - root_mean_squared_error: 146167.5625 - val_loss: 13447826432.0000 - val_root_mean_squared_error: 115964.7656
# Epoch 4/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11170482176.0000 - root_mean_squared_error: 105448.4453 - val_loss: 5566045696.0000 - val_root_mean_squared_error: 74605.9375
# Epoch 5/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5325773824.0000 - root_mean_squared_error: 72956.3984 - val_loss: 5237164032.0000 - val_root_mean_squared_error: 72368.2500
# Epoch 6/100
# ...

# %%
from tensorflow.keras.models import load_model
simple_nn=load_model('models/simple_nn.keras')
mse(simple_nn.predict(X_train),y_train,squared=False),mse(simple_nn.predict(X_val),y_val,squared=False)
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (66090.38065706131, 68727.16810343308)

# %%
medium_nn=Sequential()
medium_nn.add(InputLayer((13,)))
medium_nn.add(Dense(32,'relu'))
medium_nn.add(Dense(16,'relu'))
medium_nn.add(Dense(1,'linear'))

opt=Adam(learning_rate=.1)
cp=ModelCheckpoint('models/medium_nn.keras',save_best_only=True)
medium_nn.compile(optimizer=opt,loss='mse',metrics=[RootMeanSquaredError()])
medium_nn.fit(x=X_train,y=y_train,validation_data=(X_val,y_val),epochs=100,callbacks=[cp])
# Out:
# Epoch 1/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18026203136.0000 - root_mean_squared_error: 127898.8906 - val_loss: 4951988224.0000 - val_root_mean_squared_error: 70370.3672
# Epoch 2/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4403188736.0000 - root_mean_squared_error: 66318.4844 - val_loss: 4732688384.0000 - val_root_mean_squared_error: 68794.5391
# Epoch 3/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4365121536.0000 - root_mean_squared_error: 66062.6953 - val_loss: 4844451328.0000 - val_root_mean_squared_error: 69602.0938
# Epoch 4/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4223808000.0000 - root_mean_squared_error: 64970.6875 - val_loss: 4557382656.0000 - val_root_mean_squared_error: 67508.3906
# Epoch 5/100
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4293401600.0000 - root_mean_squared_error: 65510.9453 - val_loss: 4708638208.0000 - val_root_mean_squared_error: 68619.5156
# Epoch 6/100
# ...

# %%
medium_nn=load_model('models/simple_nn.keras')
mse(medium_nn.predict(X_train),y_train,squared=False),mse(medium_nn.predict(X_val),y_val,squared=False)
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (66090.38065706131, 68727.16810343308)

# %%
large_nn=Sequential()
large_nn.add(InputLayer((13,)))
large_nn.add(Dense(256,'relu'))
large_nn.add(Dense(128,'relu'))
large_nn.add(Dense(64,'relu'))
large_nn.add(Dense(32,'relu'))
large_nn.add(Dense(16,'relu'))
large_nn.add(Dense(8,'relu'))
large_nn.add(Dense(1,'relu'))

opt=Adam(learning_rate=.1)
cp=ModelCheckpoint('models/large_nn.keras',save_best_only=True)
large_nn.compile(optimizer=opt,loss='mse',metrics=[RootMeanSquaredError()])

# %%
large_nn=load_model('models/simple_nn.keras')
mse(large_nn.predict(X_train),y_train,squared=False),mse(large_nn.predict(X_val),y_val,squared=False)
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (66090.38065706131, 68727.16810343308)

# %%
mse(gb.predict(X_test),y_test,squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 58482.28320978034
